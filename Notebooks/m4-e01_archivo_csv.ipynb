# %% [markdown]
# # Trabajo con archivos y Google Colab/Drive

# %% [markdown]
# ## Forma 1 - Importando archivo
#
# - El archivo existe en la sesión.

# %%
import pandas as pd
from google.colab import files

# %%
csv = files.upload() # Activa la opción de subir archivo
# Out:
#      <input type="file" id="files-eb372e7e-6eed-41fb-baf7-f351264f4c04" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb372e7e-6eed-41fb-baf7-f351264f4c04">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(csv)
# Out:
# {'E-ShopNow (Proyecto ABP M2) (1).csv': b"id_venta;fecha_venta;id_empleado;antiguedad_vendedor;id_cliente;nombre_cliente;email_cliente;genero_cliente;edad_cliente;ciudad_cliente;region_cliente;canal_venta;producto;categoria_producto;precio_unitario;cantidad;descuento_pct\r\n1;02/01/2023;50;0;254;Mar\xc3\xada Gonz\xc3\xa1lez Alfaro;cliente254@mail.cl;Hombre;50.0;Temuco;La Araucan\xc3\xada;Web;Maquillaje;Belleza;15000;3;0.0\r\n2;03/01/2023;13;0;102;Vania Evelyn Leyton Garc\xc3\xada;cliente102@mail.cl;Hombre;32.0;Talcahuano;Biob\xc3\xado;App;Lavadora;Electrohogar;700000;2;0.05\r\n3;04/01/2023;68;2;196;Darwin Ram\xc3\xb3n Saavedra Pino;cliente196@mail.cl;Hombre;42.0;Santiago;;App;Lavadora;;700000;2;0.05\r\n4;05/01/2023;60;1;65;Manuel Rodr\xc3\xadguez;cliente65@mail.cl;Hombre;47.0;Valpara\xc3\xadso;Valpara\xc3\xadso;Tienda;Perfume;Belleza;35000;2;\r\n5;06/01/2023;11;0;218;Francisco Ra\xc3\xbal Guerrero-Romero S\xc3\xa1nchez;cliente218@mail.cl;Mujer;35.0;Antofagasta;Antofagasta;Tienda;Maqu
# ...

# %%
df = pd.read_csv("E-ShopNow (Proyecto ABP M2).csv", sep=";")

# %%
print(df.head())
# Out:
#    id_venta fecha_venta  id_empleado  antiguedad_vendedor  id_cliente  \
# 0         1  02/01/2023           50                    0         254
# 1         2  03/01/2023           13                    0         102
# 2         3  04/01/2023           68                    2         196
# 3         4  05/01/2023           60                    1          65
# 4         5  06/01/2023           11                    0         218
#
#                            nombre_cliente       email_cliente genero_cliente  \
# 0                   María González Alfaro  cliente254@mail.cl         Hombre
# 1              Vania Evelyn Leyton García  cliente102@mail.cl         Hombre
# 2              Darwin Ramón Saavedra Pino  cliente196@mail.cl         Hombre
# 3                        Manuel Rodríguez   cliente65@mail.cl         Hombre
# 4  Francisco Raúl Guerrero-Romero Sánchez  cliente218@mail.cl          Mujer
#
#    edad_cliente ciudad_cliente region_cliente canal_venta    producto  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_venta             1020 non-null   int64
#  1   fecha_venta          1020 non-null   object
#  2   id_empleado          1020 non-null   int64
#  3   antiguedad_vendedor  1020 non-null   int64
#  4   id_cliente           1020 non-null   int64
#  5   nombre_cliente       1020 non-null   object
#  6   email_cliente        1020 non-null   object
#  7   genero_cliente       1020 non-null   object
#  8   edad_cliente         1000 non-null   float64
#  9   ciudad_cliente       1020 non-null   object
#  10  region_cliente       625 non-null    object
#  11  canal_venta          1020 non-null   object
#  12  producto             1020 non-null   object
#  13  categoria_producto   631 non-null    object
#  14  precio_unitario      1020 non-null   int64
# ...

# %%
aux = df["descuento_pct"]
print( aux  )
# Out:
# 0       0.00
# 1       0.05
# 2       0.05
# 3        NaN
# 4       0.10
#         ...
# 1015    0.05
# 1016    0.00
# 1017    0.10
# 1018     NaN
# 1019    0.00
# Name: descuento_pct, Length: 1020, dtype: float64

# %% [markdown]
# ## Forma 2 - Usando Drive

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ruta = "/content/drive/MyDrive/Curso analisis de datos/data/E-ShopNow (Proyecto ABP M2).csv"

df2 = pd.read_csv(ruta, sep=";")

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_venta             1020 non-null   int64
#  1   fecha_venta          1020 non-null   object
#  2   id_empleado          1020 non-null   int64
#  3   antiguedad_vendedor  1020 non-null   int64
#  4   id_cliente           1020 non-null   int64
#  5   nombre_cliente       1020 non-null   object
#  6   email_cliente        1020 non-null   object
#  7   genero_cliente       1020 non-null   object
#  8   edad_cliente         1000 non-null   float64
#  9   ciudad_cliente       1020 non-null   object
#  10  region_cliente       625 non-null    object
#  11  canal_venta          1020 non-null   object
#  12  producto             1020 non-null   object
#  13  categoria_producto   631 non-null    object
#  14  precio_unitario      1020 non-null   int64
# ...
