# %% [markdown]
# # Fundamentos de Python
# **Variables**
# - Nombre
# - Tipo de dato
# - Valor

# %%
nombre = "Germán"
print(nombre)
print(id(nombre)) # Ubicación de la variable en memoria
print(type(nombre)) # Tipo de dato
# Out:
# Germán
# 135364761672688
# <class 'str'>

# %% [markdown]
# ## Uso de comentarios
#
# Los comentarios me permiten documentar el código y estas líneas no se ejecutan

# %%
nombre = "Ruth"

"""
Este es un comentario
de varias líneas
"""

print(nombre)
# Out:
# Ruth

# %% [markdown]
# ## Trabajando con números

# %%
edad = 25
print(edad)
# Out:
# 25

# %%
# Diferencia a nivel de ciencias de la computación de varibles
# int y str (enteros y cadenas de texto)

esto_es_un_numero = 10
esto_es_otro_numero = 20
print(esto_es_un_numero + esto_es_otro_numero)

esto_no_es_un_numero = "10"
esto_tampoco_es_un_numero = "20"
print(esto_no_es_un_numero + esto_tampoco_es_un_numero)
print(type(esto_no_es_un_numero))
print(type(esto_tampoco_es_un_numero))
# Out:
# 30
# 1020
# <class 'str'>
# <class 'str'>
